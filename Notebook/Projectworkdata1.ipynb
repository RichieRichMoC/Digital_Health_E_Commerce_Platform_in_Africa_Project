# %% [markdown]
# ## DATA UNDERSTANDING
# ## Importation

# %%
# %pip install pandas
# %pip install python-dotenv
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install plotly
# %pip install imbalanced-learn
# %pip install plotly-express
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (1.46.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: imbalanced-learn in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (1.13.0)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from imbalanced-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly-express in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (2.2.2)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (6.2.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (0.14.4)
# Requirement already satisfied: scipy>=0.18 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (1.13.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (1.0.1)
# Requirement already satisfied: numpy>=1.11 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly-express) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.20.0->plotly-express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.20.0->plotly-express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.20.0->plotly-express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=4.1.0->plotly-express) (1.46.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from plotly>=4.1.0->plotly-express) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly-express) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\HP\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Import necessary libraries for data handling 

import pandas as pd
import numpy as np
from dotenv import dotenv_values

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 

# hypothesis testing
from scipy.stats import chi2_contingency

# Machine learning classification model from sklean
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Feature Processing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.preprocessing import FunctionTransformer,OneHotEncoder,LabelEncoder,OrdinalEncoder
from sklearn.base import TransformerMixin
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from functools import partial
from sklearn.metrics import roc_auc_score, roc_curve, auc

# class imbalance
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.pipeline import Pipeline as impipeline

# Hyperparameters Fine-tuning
from sklearn.model_selection import GridSearchCV

# Other utilities
import joblib
import os
import pickle


# Import necessary libraries for data handling 
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 

# hypothesis testing
from scipy.stats import chi2_contingency

# Machine learning classification model from sklean
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Feature Processing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.preprocessing import FunctionTransformer,OneHotEncoder,LabelEncoder,OrdinalEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from functools import partial
from sklearn.metrics import roc_curve, auc
from sklearn.ensemble import  GradientBoostingClassifier

# class imbalance
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.pipeline import Pipeline as impipeline

# Hyperparameters Fine-tuning
from sklearn.model_selection import GridSearchCV

# Other utilities
import joblib
import os
import pickle

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Loading

# %%
Data_on_Economic_Growth_indicator = pd.read_csv('../DB/Data_on_Economic_Growth_indicator.csv')
Data_on_Economic_Growth_indicator
# Out:
#         STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 1   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 2   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 3   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 4   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 5   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 6   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 7   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 8   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 9   datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 10  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 11  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 12  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 13  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 14  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 15  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 16  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 17  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 18  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 19  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 20  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 21  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 22  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 23  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 24  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 25  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 26  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 27  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 28  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 29  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 30  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 31  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 32  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 33  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 34  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 35  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 36  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 37  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 38  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 39  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 40  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 41  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 42  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 43  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 44  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 45  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 46  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 47  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 48  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 49  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 50  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
#
#    Country Code Country Name                 Series Code  \
# 0           GHA        Ghana                 FAO_AS_4458
# 1           GHA        Ghana                 FAO_AS_4458
# 2           GHA        Ghana                 FAO_AS_4458
# 3           GHA        Ghana                 FAO_AS_4458
# 4           GHA        Ghana                 FAO_AS_4458
# 5           GHA        Ghana                 FAO_AS_4458
# 6           GHA        Ghana                 FAO_AS_4458
# 7           KEN        Kenya                 FAO_AS_4458
# 8           KEN        Kenya                 FAO_AS_4458
# 9           KEN        Kenya                 FAO_AS_4458
# 10          KEN        Kenya                 FAO_AS_4458
# 11          KEN        Kenya                 FAO_AS_4458
# 12          KEN        Kenya                 FAO_AS_4458
# 13          KEN        Kenya                 FAO_AS_4458
# 14          NGA      Nigeria                 FAO_AS_4458
# 15          NGA      Nigeria                 FAO_AS_4458
# 16          NGA      Nigeria                 FAO_AS_4458
# 17          NGA      Nigeria                 FAO_AS_4458
# 18          NGA      Nigeria                 FAO_AS_4458
# 19          NGA      Nigeria                 FAO_AS_4458
# 20          NGA      Nigeria                 FAO_AS_4458
# 21          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 22          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 23          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 24          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 25          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 26          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 27          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 28          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 29          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 30          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 31          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 32          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 33          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 34          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 35          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 36          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 37          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 38          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 39          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 40          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 41          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 42          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 43          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 44          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 45          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 46          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 47          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 48          GHA        Ghana  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 49          KEN        Kenya  WB_CLEAR_NY_GDP_MKTP_KD_ZG
# 50          NGA      Nigeria  WB_CLEAR_NY_GDP_MKTP_KD_ZG
#
#               Series Name SEX  ... DATA_SOURCE_LABEL UNIT_TYPE  \
# 0          GDP per capita  _T  ...          Aquastat       CUR
# 1          GDP per capita  _T  ...          Aquastat       CUR
# 2          GDP per capita  _T  ...          Aquastat       CUR
# 3          GDP per capita  _T  ...          Aquastat       CUR
# 4          GDP per capita  _T  ...          Aquastat       CUR
# 5          GDP per capita  _T  ...          Aquastat       CUR
# 6          GDP per capita  _T  ...          Aquastat       CUR
# 7          GDP per capita  _T  ...          Aquastat       CUR
# 8          GDP per capita  _T  ...          Aquastat       CUR
# 9          GDP per capita  _T  ...          Aquastat       CUR
# 10         GDP per capita  _T  ...          Aquastat       CUR
# 11         GDP per capita  _T  ...          Aquastat       CUR
# 12         GDP per capita  _T  ...          Aquastat       CUR
# 13         GDP per capita  _T  ...          Aquastat       CUR
# 14         GDP per capita  _T  ...          Aquastat       CUR
# 15         GDP per capita  _T  ...          Aquastat       CUR
# 16         GDP per capita  _T  ...          Aquastat       CUR
# 17         GDP per capita  _T  ...          Aquastat       CUR
# 18         GDP per capita  _T  ...          Aquastat       CUR
# 19         GDP per capita  _T  ...          Aquastat       CUR
# 20         GDP per capita  _T  ...          Aquastat       CUR
# 21  GDP growth (annual %)  _T  ...               NaN       NaN
# 22  GDP growth (annual %)  _T  ...               NaN       NaN
# 23  GDP growth (annual %)  _T  ...               NaN       NaN
# 24  GDP growth (annual %)  _T  ...               NaN       NaN
# 25  GDP growth (annual %)  _T  ...               NaN       NaN
# 26  GDP growth (annual %)  _T  ...               NaN       NaN
# 27  GDP growth (annual %)  _T  ...               NaN       NaN
# 28  GDP growth (annual %)  _T  ...               NaN       NaN
# 29  GDP growth (annual %)  _T  ...               NaN       NaN
# 30  GDP growth (annual %)  _T  ...               NaN       NaN
# 31  GDP growth (annual %)  _T  ...               NaN       NaN
# 32  GDP growth (annual %)  _T  ...               NaN       NaN
# 33  GDP growth (annual %)  _T  ...               NaN       NaN
# 34  GDP growth (annual %)  _T  ...               NaN       NaN
# 35  GDP growth (annual %)  _T  ...               NaN       NaN
# 36  GDP growth (annual %)  _T  ...               NaN       NaN
# 37  GDP growth (annual %)  _T  ...               NaN       NaN
# 38  GDP growth (annual %)  _T  ...               NaN       NaN
# 39  GDP growth (annual %)  _T  ...               NaN       NaN
# 40  GDP growth (annual %)  _T  ...               NaN       NaN
# 41  GDP growth (annual %)  _T  ...               NaN       NaN
# 42  GDP growth (annual %)  _T  ...               NaN       NaN
# 43  GDP growth (annual %)  _T  ...               NaN       NaN
# 44  GDP growth (annual %)  _T  ...               NaN       NaN
# 45  GDP growth (annual %)  _T  ...               NaN       NaN
# 46  GDP growth (annual %)  _T  ...               NaN       NaN
# 47  GDP growth (annual %)  _T  ...               NaN       NaN
# 48  GDP growth (annual %)  _T  ...               NaN       NaN
# 49  GDP growth (annual %)  _T  ...               NaN       NaN
# 50  GDP growth (annual %)  _T  ...               NaN       NaN
#
#    UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0         Currency         602              CCYY
# 1         Currency         602              CCYY
# 2         Currency         602              CCYY
# 3         Currency         602              CCYY
# 4         Currency         602              CCYY
# 5         Currency         602              CCYY
# 6         Currency         602              CCYY
# 7         Currency         602              CCYY
# 8         Currency         602              CCYY
# 9         Currency         602              CCYY
# 10        Currency         602              CCYY
# 11        Currency         602              CCYY
# 12        Currency         602              CCYY
# 13        Currency         602              CCYY
# 14        Currency         602              CCYY
# 15        Currency         602              CCYY
# 16        Currency         602              CCYY
# 17        Currency         602              CCYY
# 18        Currency         602              CCYY
# 19        Currency         602              CCYY
# 20        Currency         602              CCYY
# 21              PU      Public               NaN
# 22              PU      Public               NaN
# 23              PU      Public               NaN
# 24              PU      Public               NaN
# 25              PU      Public               NaN
# 26              PU      Public               NaN
# 27              PU      Public               NaN
# 28              PU      Public               NaN
# 29              PU      Public               NaN
# 30              PU      Public               NaN
# 31              PU      Public               NaN
# 32              PU      Public               NaN
# 33              PU      Public               NaN
# 34              PU      Public               NaN
# 35              PU      Public               NaN
# 36              PU      Public               NaN
# 37              PU      Public               NaN
# 38              PU      Public               NaN
# 39              PU      Public               NaN
# 40              PU      Public               NaN
# 41              PU      Public               NaN
# 42              PU      Public               NaN
# 43              PU      Public               NaN
# 44              PU      Public               NaN
# 45              PU      Public               NaN
# 46              PU      Public               NaN
# 47              PU      Public               NaN
# 48              PU      Public               NaN
# 49              PU      Public               NaN
# 50              PU      Public               NaN
#
#                                           COMMENT_OBS OBS_STATUS  \
# 0   External value (reported by FAOSTAT or another...          X
# 1   External value (reported by FAOSTAT or another...          X
# 2   External value (reported by FAOSTAT or another...          X
# 3   External value (reported by FAOSTAT or another...          X
# 4   External value (reported by FAOSTAT or another...          X
# 5   External value (reported by FAOSTAT or another...          X
# 6   External value (reported by FAOSTAT or another...          X
# 7   External value (reported by FAOSTAT or another...          X
# 8   External value (reported by FAOSTAT or another...          X
# 9   External value (reported by FAOSTAT or another...          X
# 10  External value (reported by FAOSTAT or another...          X
# 11  External value (reported by FAOSTAT or another...          X
# 12  External value (reported by FAOSTAT or another...          X
# 13  External value (reported by FAOSTAT or another...          X
# 14  External value (reported by FAOSTAT or another...          X
# 15  External value (reported by FAOSTAT or another...          X
# 16  External value (reported by FAOSTAT or another...          X
# 17  External value (reported by FAOSTAT or another...          X
# 18  External value (reported by FAOSTAT or another...          X
# 19  External value (reported by FAOSTAT or another...          X
# 20  External value (reported by FAOSTAT or another...          X
# 21                                                NaN        NaN
# 22                                                NaN        NaN
# 23                                                NaN        NaN
# 24                                                NaN        NaN
# 25                                                NaN        NaN
# 26                                                NaN        NaN
# 27                                                NaN        NaN
# 28                                                NaN        NaN
# 29                                                NaN        NaN
# 30                                                NaN        NaN
# 31                                                NaN        NaN
# 32                                                NaN        NaN
# 33                                                NaN        NaN
# 34                                                NaN        NaN
# 35                                                NaN        NaN
# 36                                                NaN        NaN
# 37                                                NaN        NaN
# 38                                                NaN        NaN
# 39                                                NaN        NaN
# 40                                                NaN        NaN
# 41                                                NaN        NaN
# 42                                                NaN        NaN
# 43                                                NaN        NaN
# 44                                                NaN        NaN
# 45                                                NaN        NaN
# 46                                                NaN        NaN
# 47                                                NaN        NaN
# 48                                                NaN        NaN
# 49                                                NaN        NaN
# 50                                                NaN        NaN
#
#                            OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0   Figure from international organizations       PU         Public
# 1   Figure from international organizations       PU         Public
# 2   Figure from international organizations       PU         Public
# 3   Figure from international organizations       PU         Public
# 4   Figure from international organizations       PU         Public
# 5   Figure from international organizations       PU         Public
# 6   Figure from international organizations       PU         Public
# 7   Figure from international organizations       PU         Public
# 8   Figure from international organizations       PU         Public
# 9   Figure from international organizations       PU         Public
# 10  Figure from international organizations       PU         Public
# 11  Figure from international organizations       PU         Public
# 12  Figure from international organizations       PU         Public
# 13  Figure from international organizations       PU         Public
# 14  Figure from international organizations       PU         Public
# 15  Figure from international organizations       PU         Public
# 16  Figure from international organizations       PU         Public
# 17  Figure from international organizations       PU         Public
# 18  Figure from international organizations       PU         Public
# 19  Figure from international organizations       PU         Public
# 20  Figure from international organizations       PU         Public
# 21                                      NaN      NaN            NaN
# 22                                      NaN      NaN            NaN
# 23                                      NaN      NaN            NaN
# 24                                      NaN      NaN            NaN
# 25                                      NaN      NaN            NaN
# 26                                      NaN      NaN            NaN
# 27                                      NaN      NaN            NaN
# 28                                      NaN      NaN            NaN
# 29                                      NaN      NaN            NaN
# 30                                      NaN      NaN            NaN
# 31                                      NaN      NaN            NaN
# 32                                      NaN      NaN            NaN
# 33                                      NaN      NaN            NaN
# 34                                      NaN      NaN            NaN
# 35                                      NaN      NaN            NaN
# 36                                      NaN      NaN            NaN
# 37                                      NaN      NaN            NaN
# 38                                      NaN      NaN            NaN
# 39                                      NaN      NaN            NaN
# 40                                      NaN      NaN            NaN
# 41                                      NaN      NaN            NaN
# 42                                      NaN      NaN            NaN
# 43                                      NaN      NaN            NaN
# 44                                      NaN      NaN            NaN
# 45                                      NaN      NaN            NaN
# 46                                      NaN      NaN            NaN
# 47                                      NaN      NaN            NaN
# 48                                      NaN      NaN            NaN
# 49                                      NaN      NaN            NaN
# 50                                      NaN      NaN            NaN
#
# [51 rows x 43 columns]

# %% [markdown]
# ## Data understanding & EDA

# %%
# Identify year columns (those containing 'YR')
year_cols = [col for col in Data_on_Economic_Growth_indicator.columns if "[YR" in col]

# Convert to numeric and fill NaN with 0
Data_on_Economic_Growth_indicator[year_cols] = Data_on_Economic_Growth_indicator[year_cols].apply(pd.to_numeric, errors="coerce").fillna(0)

# (Optional) also apply to df1, df2, df3 if they have same structure
# df1[year_cols] = df1[year_cols].apply(pd.to_numeric, errors="coerce").fillna(0)
# df2[year_cols] = df2[year_cols].apply(pd.to_numeric, errors="coerce").fillna(0)
# df3[year_cols] = df3[year_cols].apply(pd.to_numeric, errors="coerce").fillna(0)

# %%
# Overview
print(Data_on_Economic_Growth_indicator.shape)
print(Data_on_Economic_Growth_indicator.info())
print(Data_on_Economic_Growth_indicator.head())

# Check unique values
for col in Data_on_Economic_Growth_indicator.columns:
    print(f"\n{col} ({Data_on_Economic_Growth_indicator[col].dtype}): {Data_on_Economic_Growth_indicator[col].nunique()} unique values")
    print(Data_on_Economic_Growth_indicator[col].unique())
# Out:
# (51, 43)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               51 non-null     object
#  1   STRUCTURE_ID            51 non-null     object
#  2   ACTION                  51 non-null     object
#  3   FREQ                    51 non-null     object
#  4   FREQ_LABEL              51 non-null     object
#  5   Country Code            51 non-null     object
#  6   Country Name            51 non-null     object
#  7   Series Code             51 non-null     object
#  8   Series Name             51 non-null     object
#  9   SEX                     51 non-null     object
#  10  SEX_LABEL               51 non-null     object
#  11  AGE                     51 non-null     object
#  12  AGE_LABEL               51 non-null     object
#  13  URBANISATION            51 non-null     object
#  14  URBANISATION_LABEL      51 non-null     object
#  15  UNIT_MEASURE            51 non-null     object
#  16  UNIT_MEASURE_LABEL      51 non-null     object
#  17  COMP_BREAKDOWN_1        51 non-null     object
#  18  COMP_BREAKDOWN_1_LABEL  51 non-null     object
#  19  COMP_BREAKDOWN_2        51 non-null     object
#  20  COMP_BREAKDOWN_2_LABEL  51 non-null     object
#  21  COMP_BREAKDOWN_3        51 non-null     object
#  22  COMP_BREAKDOWN_3_LABEL  51 non-null     object
#  23  Year                    51 non-null     int64
#  24  OBS_VALUE               51 non-null     float64
#  25  DECIMALS                51 non-null     object
#  26  DECIMALS_LABEL          51 non-null     object
#  27  DATABASE_ID             51 non-null     object
#  28  DATABASE_ID_LABEL       51 non-null     object
#  29  COMMENT_TS              30 non-null     object
#  30  UNIT_MULT               51 non-null     object
#  31  UNIT_MULT_LABEL         51 non-null     object
#  32  DATA_SOURCE             51 non-null     object
#  33  DATA_SOURCE_LABEL       21 non-null     object
#  34  UNIT_TYPE               21 non-null     object
#  35  UNIT_TYPE_LABEL         51 non-null     object
#  36  TIME_FORMAT             51 non-null     object
#  37  TIME_FORMAT_LABEL       21 non-null     object
#  38  COMMENT_OBS             21 non-null     object
#  39  OBS_STATUS              21 non-null     object
#  40  OBS_STATUS_LABEL        21 non-null     object
#  41  OBS_CONF                21 non-null     object
#  42  OBS_CONF_LABEL          21 non-null     object
# dtypes: float64(1), int64(1), object(41)
# memory usage: 17.3+ KB
# None
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
#
#   Country Code Country Name  Series Code     Series Name SEX  ...  \
# 0          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 1          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 2          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 3          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 4          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
#
#   DATA_SOURCE_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0          Aquastat       CUR        Currency         602              CCYY
# 1          Aquastat       CUR        Currency         602              CCYY
# 2          Aquastat       CUR        Currency         602              CCYY
# 3          Aquastat       CUR        Currency         602              CCYY
# 4          Aquastat       CUR        Currency         602              CCYY
#
#                                          COMMENT_OBS OBS_STATUS  \
# 0  External value (reported by FAOSTAT or another...          X
# 1  External value (reported by FAOSTAT or another...          X
# 2  External value (reported by FAOSTAT or another...          X
# 3  External value (reported by FAOSTAT or another...          X
# 4  External value (reported by FAOSTAT or another...          X
#
#                           OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0  Figure from international organizations       PU         Public
# 1  Figure from international organizations       PU         Public
# 2  Figure from international organizations       PU         Public
# 3  Figure from international organizations       PU         Public
# 4  Figure from international organizations       PU         Public
#
# [5 rows x 43 columns]
#
# STRUCTURE (object): 1 unique values
# ['datastructure']
#
# STRUCTURE_ID (object): 1 unique values
# ['WB.DATA360:DS_DATA360(1.2)']
#
# ACTION (object): 1 unique values
# ['I']
#
# FREQ (object): 1 unique values
# ['A']
#
# FREQ_LABEL (object): 1 unique values
# ['Annual']
#
# Country Code (object): 3 unique values
# ['GHA' 'KEN' 'NGA']
#
# Country Name (object): 3 unique values
# ['Ghana' 'Kenya' 'Nigeria']
#
# Series Code (object): 2 unique values
# ['FAO_AS_4458' 'WB_CLEAR_NY_GDP_MKTP_KD_ZG']
#
# Series Name (object): 2 unique values
# ['GDP per capita' 'GDP growth (annual %)']
#
# SEX (object): 1 unique values
# ['_T']
#
# SEX_LABEL (object): 1 unique values
# ['Total']
#
# AGE (object): 1 unique values
# ['_T']
#
# AGE_LABEL (object): 1 unique values
# ['All age ranges or no breakdown by age']
#
# URBANISATION (object): 1 unique values
# ['_T']
#
# URBANISATION_LABEL (object): 1 unique values
# ['Total']
#
# UNIT_MEASURE (object): 2 unique values
# ['USD' 'PT']
#
# UNIT_MEASURE_LABEL (object): 2 unique values
# ['US dollars' 'Percentage']
#
# COMP_BREAKDOWN_1 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_1_LABEL (object): 1 unique values
# ['Not Applicable']
#
# COMP_BREAKDOWN_2 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_2_LABEL (object): 1 unique values
# ['Not Applicable']
#
# COMP_BREAKDOWN_3 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_3_LABEL (object): 1 unique values
# ['Not Applicable']
#
# Year (int64): 10 unique values
# [2014 2015 2016 2017 2018 2019 2020 2021 2022 2023]
#
# OBS_VALUE (float64): 51 unique values
# [ 2.01006151e+03  1.79660108e+03  1.97195707e+03  2.07417544e+03
#   2.26011345e+03  2.24714975e+03  2.20552609e+03  1.44146060e+03
#   1.46455480e+03  1.52523556e+03  1.63406874e+03  1.79409181e+03
#   1.91262330e+03  1.87858119e+03  3.22269211e+03  2.73042714e+03
#   2.17599807e+03  1.96868724e+03  2.15352649e+03  2.36120697e+03
#   2.08547406e+03  2.85624016e+00  5.02011100e+00  6.30971866e+00
#   2.12075934e+00  4.96772113e+00  2.65269330e+00  3.37346575e+00
#   4.21351707e+00 -1.61686895e+00  8.12889488e+00  3.83795817e+00
#   8.05886619e-01  6.20007768e+00  5.64794641e+00  1.92275734e+00
#   6.50777479e+00  5.11415886e+00  2.20842928e+00  5.13941671e-01
#  -2.72766327e-01 -1.79425308e+00  5.07646644e+00  7.59048947e+00
#   3.64718654e+00  3.81750462e+00  4.84663486e+00  3.25168141e+00
#   2.94478583e+00  5.42581615e+00  2.86021499e+00]
#
# DECIMALS (object): 2 unique values
# ['2' 'WB_CLEAR']
#
# DECIMALS_LABEL (object): 2 unique values
# ['Two'
#  'Climate and Economic Analyses for Resilience in Water - CLEAR Water']
#
# DATABASE_ID (object): 2 unique values
# ['FAO_AS' '0']
#
# DATABASE_ID_LABEL (object): 2 unique values
# ['Aquastat' 'Units']
#
# COMMENT_TS (object): 1 unique values
# [nan 'NUMBER']
#
# UNIT_MULT (object): 2 unique values
# ['0' 'Number (real number)']
#
# UNIT_MULT_LABEL (object): 2 unique values
# ['Units' 'P1Y']
#
# DATA_SOURCE (object): 2 unique values
# ['FAO_AS' 'Annual']
#
# DATA_SOURCE_LABEL (object): 1 unique values
# ['Aquastat' nan]
#
# UNIT_TYPE (object): 1 unique values
# ['CUR' nan]
#
# UNIT_TYPE_LABEL (object): 2 unique values
# ['Currency' 'PU']
#
# TIME_FORMAT (object): 2 unique values
# ['602' 'Public']
#
# TIME_FORMAT_LABEL (object): 1 unique values
# ['CCYY' nan]
#
# COMMENT_OBS (object): 1 unique values
# ['External value (reported by FAOSTAT or another international agency)'
#  nan]
#
# OBS_STATUS (object): 1 unique values
# ['X' nan]
#
# OBS_STATUS_LABEL (object): 1 unique values
# ['Figure from international organizations' nan]
#
# OBS_CONF (object): 1 unique values
# ['PU' nan]
#
# OBS_CONF_LABEL (object): 1 unique values
# ['Public' nan]

# %% [markdown]
# - **Insight📣**
#
# The DataFrame contains 1,077,024 entries and 19 columns. Some columns have missing values (NaN), which may require handling during data preprocessing.

# %%
# Assuming your dataframe is called df
Data_on_Economic_Growth_indicator["Year"] = pd.to_datetime(Data_on_Economic_Growth_indicator["Year"].astype(str), format="%Y")

# If you want just the year displayed (without month/day clutter):
Data_on_Economic_Growth_indicator["Year"] = Data_on_Economic_Growth_indicator["Year"].dt.to_period("Y")

# %%
# Overview
print(Data_on_Economic_Growth_indicator.shape)
print(Data_on_Economic_Growth_indicator.info())
print(Data_on_Economic_Growth_indicator.head())

# Check unique values
for col in Data_on_Economic_Growth_indicator.columns:
    print(f"\n{col} ({Data_on_Economic_Growth_indicator[col].dtype}): {Data_on_Economic_Growth_indicator[col].nunique()} unique values")
    print(Data_on_Economic_Growth_indicator[col].unique())
# Out:
# (51, 43)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               51 non-null     object
#  1   STRUCTURE_ID            51 non-null     object
#  2   ACTION                  51 non-null     object
#  3   FREQ                    51 non-null     object
#  4   FREQ_LABEL              51 non-null     object
#  5   Country Code            51 non-null     object
#  6   Country Name            51 non-null     object
#  7   Series Code             51 non-null     object
#  8   Series Name             51 non-null     object
#  9   SEX                     51 non-null     object
#  10  SEX_LABEL               51 non-null     object
#  11  AGE                     51 non-null     object
#  12  AGE_LABEL               51 non-null     object
#  13  URBANISATION            51 non-null     object
#  14  URBANISATION_LABEL      51 non-null     object
#  15  UNIT_MEASURE            51 non-null     object
#  16  UNIT_MEASURE_LABEL      51 non-null     object
#  17  COMP_BREAKDOWN_1        51 non-null     object
#  18  COMP_BREAKDOWN_1_LABEL  51 non-null     object
#  19  COMP_BREAKDOWN_2        51 non-null     object
#  20  COMP_BREAKDOWN_2_LABEL  51 non-null     object
#  21  COMP_BREAKDOWN_3        51 non-null     object
#  22  COMP_BREAKDOWN_3_LABEL  51 non-null     object
#  23  Year                    51 non-null     period[Y-DEC]
#  24  OBS_VALUE               51 non-null     float64
#  25  DECIMALS                51 non-null     object
#  26  DECIMALS_LABEL          51 non-null     object
#  27  DATABASE_ID             51 non-null     object
#  28  DATABASE_ID_LABEL       51 non-null     object
#  29  COMMENT_TS              30 non-null     object
#  30  UNIT_MULT               51 non-null     object
#  31  UNIT_MULT_LABEL         51 non-null     object
#  32  DATA_SOURCE             51 non-null     object
#  33  DATA_SOURCE_LABEL       21 non-null     object
#  34  UNIT_TYPE               21 non-null     object
#  35  UNIT_TYPE_LABEL         51 non-null     object
#  36  TIME_FORMAT             51 non-null     object
#  37  TIME_FORMAT_LABEL       21 non-null     object
#  38  COMMENT_OBS             21 non-null     object
#  39  OBS_STATUS              21 non-null     object
#  40  OBS_STATUS_LABEL        21 non-null     object
#  41  OBS_CONF                21 non-null     object
#  42  OBS_CONF_LABEL          21 non-null     object
# dtypes: float64(1), object(41), period[Y-DEC](1)
# memory usage: 17.3+ KB
# None
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
#
#   Country Code Country Name  Series Code     Series Name SEX  ...  \
# 0          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 1          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 2          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 3          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
# 4          GHA        Ghana  FAO_AS_4458  GDP per capita  _T  ...
#
#   DATA_SOURCE_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL  \
# 0          Aquastat       CUR        Currency         602              CCYY
# 1          Aquastat       CUR        Currency         602              CCYY
# 2          Aquastat       CUR        Currency         602              CCYY
# 3          Aquastat       CUR        Currency         602              CCYY
# 4          Aquastat       CUR        Currency         602              CCYY
#
#                                          COMMENT_OBS OBS_STATUS  \
# 0  External value (reported by FAOSTAT or another...          X
# 1  External value (reported by FAOSTAT or another...          X
# 2  External value (reported by FAOSTAT or another...          X
# 3  External value (reported by FAOSTAT or another...          X
# 4  External value (reported by FAOSTAT or another...          X
#
#                           OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0  Figure from international organizations       PU         Public
# 1  Figure from international organizations       PU         Public
# 2  Figure from international organizations       PU         Public
# 3  Figure from international organizations       PU         Public
# 4  Figure from international organizations       PU         Public
#
# [5 rows x 43 columns]
#
# STRUCTURE (object): 1 unique values
# ['datastructure']
#
# STRUCTURE_ID (object): 1 unique values
# ['WB.DATA360:DS_DATA360(1.2)']
#
# ACTION (object): 1 unique values
# ['I']
#
# FREQ (object): 1 unique values
# ['A']
#
# FREQ_LABEL (object): 1 unique values
# ['Annual']
#
# Country Code (object): 3 unique values
# ['GHA' 'KEN' 'NGA']
#
# Country Name (object): 3 unique values
# ['Ghana' 'Kenya' 'Nigeria']
#
# Series Code (object): 2 unique values
# ['FAO_AS_4458' 'WB_CLEAR_NY_GDP_MKTP_KD_ZG']
#
# Series Name (object): 2 unique values
# ['GDP per capita' 'GDP growth (annual %)']
#
# SEX (object): 1 unique values
# ['_T']
#
# SEX_LABEL (object): 1 unique values
# ['Total']
#
# AGE (object): 1 unique values
# ['_T']
#
# AGE_LABEL (object): 1 unique values
# ['All age ranges or no breakdown by age']
#
# URBANISATION (object): 1 unique values
# ['_T']
#
# URBANISATION_LABEL (object): 1 unique values
# ['Total']
#
# UNIT_MEASURE (object): 2 unique values
# ['USD' 'PT']
#
# UNIT_MEASURE_LABEL (object): 2 unique values
# ['US dollars' 'Percentage']
#
# COMP_BREAKDOWN_1 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_1_LABEL (object): 1 unique values
# ['Not Applicable']
#
# COMP_BREAKDOWN_2 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_2_LABEL (object): 1 unique values
# ['Not Applicable']
#
# COMP_BREAKDOWN_3 (object): 1 unique values
# ['_Z']
#
# COMP_BREAKDOWN_3_LABEL (object): 1 unique values
# ['Not Applicable']
#
# Year (period[Y-DEC]): 10 unique values
# <PeriodArray>
# ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#  '2023']
# Length: 10, dtype: period[Y-DEC]
#
# OBS_VALUE (float64): 51 unique values
# [ 2.01006151e+03  1.79660108e+03  1.97195707e+03  2.07417544e+03
#   2.26011345e+03  2.24714975e+03  2.20552609e+03  1.44146060e+03
#   1.46455480e+03  1.52523556e+03  1.63406874e+03  1.79409181e+03
#   1.91262330e+03  1.87858119e+03  3.22269211e+03  2.73042714e+03
#   2.17599807e+03  1.96868724e+03  2.15352649e+03  2.36120697e+03
#   2.08547406e+03  2.85624016e+00  5.02011100e+00  6.30971866e+00
#   2.12075934e+00  4.96772113e+00  2.65269330e+00  3.37346575e+00
#   4.21351707e+00 -1.61686895e+00  8.12889488e+00  3.83795817e+00
#   8.05886619e-01  6.20007768e+00  5.64794641e+00  1.92275734e+00
#   6.50777479e+00  5.11415886e+00  2.20842928e+00  5.13941671e-01
#  -2.72766327e-01 -1.79425308e+00  5.07646644e+00  7.59048947e+00
#   3.64718654e+00  3.81750462e+00  4.84663486e+00  3.25168141e+00
#   2.94478583e+00  5.42581615e+00  2.86021499e+00]
#
# DECIMALS (object): 2 unique values
# ['2' 'WB_CLEAR']
#
# DECIMALS_LABEL (object): 2 unique values
# ['Two'
#  'Climate and Economic Analyses for Resilience in Water - CLEAR Water']
#
# DATABASE_ID (object): 2 unique values
# ['FAO_AS' '0']
#
# DATABASE_ID_LABEL (object): 2 unique values
# ['Aquastat' 'Units']
#
# COMMENT_TS (object): 1 unique values
# [nan 'NUMBER']
#
# UNIT_MULT (object): 2 unique values
# ['0' 'Number (real number)']
#
# UNIT_MULT_LABEL (object): 2 unique values
# ['Units' 'P1Y']
#
# DATA_SOURCE (object): 2 unique values
# ['FAO_AS' 'Annual']
#
# DATA_SOURCE_LABEL (object): 1 unique values
# ['Aquastat' nan]
#
# UNIT_TYPE (object): 1 unique values
# ['CUR' nan]
#
# UNIT_TYPE_LABEL (object): 2 unique values
# ['Currency' 'PU']
#
# TIME_FORMAT (object): 2 unique values
# ['602' 'Public']
#
# TIME_FORMAT_LABEL (object): 1 unique values
# ['CCYY' nan]
#
# COMMENT_OBS (object): 1 unique values
# ['External value (reported by FAOSTAT or another international agency)'
#  nan]
#
# OBS_STATUS (object): 1 unique values
# ['X' nan]
#
# OBS_STATUS_LABEL (object): 1 unique values
# ['Figure from international organizations' nan]
#
# OBS_CONF (object): 1 unique values
# ['PU' nan]
#
# OBS_CONF_LABEL (object): 1 unique values
# ['Public' nan]

# %%
# check for duplicates
dup = Data_on_Economic_Growth_indicator.duplicated().sum()
print(f'This dataset has',dup,'duplicates')
# Out:
# This dataset has 0 duplicates

# %%
duplicates = Data_on_Economic_Growth_indicator[Data_on_Economic_Growth_indicator.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [STRUCTURE, STRUCTURE_ID, ACTION, FREQ, FREQ_LABEL, Country Code, Country Name, Series Code, Series Name, SEX, SEX_LABEL, AGE, AGE_LABEL, URBANISATION, URBANISATION_LABEL, UNIT_MEASURE, UNIT_MEASURE_LABEL, COMP_BREAKDOWN_1, COMP_BREAKDOWN_1_LABEL, COMP_BREAKDOWN_2, COMP_BREAKDOWN_2_LABEL, COMP_BREAKDOWN_3, COMP_BREAKDOWN_3_LABEL, Year, OBS_VALUE, DECIMALS, DECIMALS_LABEL, DATABASE_ID, DATABASE_ID_LABEL, COMMENT_TS, UNIT_MULT, UNIT_MULT_LABEL, DATA_SOURCE, DATA_SOURCE_LABEL, UNIT_TYPE, UNIT_TYPE_LABEL, TIME_FORMAT, TIME_FORMAT_LABEL, COMMENT_OBS, OBS_STATUS, OBS_STATUS_LABEL, OBS_CONF, OBS_CONF_LABEL]
# Index: []
#
# [0 rows x 43 columns]

# %%
# Remove duplicates and update the DataFrame
Data_on_Economic_Growth_indicator.drop_duplicates(inplace=True)

# Confirm it's done
print("Duplicates removed. New shape:", Data_on_Economic_Growth_indicator.shape)
# Out:
# Duplicates removed. New shape: (51, 43)

# %%
# check null values
Data_on_Economic_Growth_indicator.isnull().sum()
# Out:
# STRUCTURE                  0
# STRUCTURE_ID               0
# ACTION                     0
# FREQ                       0
# FREQ_LABEL                 0
# Country Code               0
# Country Name               0
# Series Code                0
# Series Name                0
# SEX                        0
# SEX_LABEL                  0
# AGE                        0
# AGE_LABEL                  0
# URBANISATION               0
# URBANISATION_LABEL         0
# UNIT_MEASURE               0
# UNIT_MEASURE_LABEL         0
# COMP_BREAKDOWN_1           0
# COMP_BREAKDOWN_1_LABEL     0
# COMP_BREAKDOWN_2           0
# COMP_BREAKDOWN_2_LABEL     0
# COMP_BREAKDOWN_3           0
# COMP_BREAKDOWN_3_LABEL     0
# Year                       0
# OBS_VALUE                  0
# DECIMALS                   0
# DECIMALS_LABEL             0
# DATABASE_ID                0
# DATABASE_ID_LABEL          0
# COMMENT_TS                21
# UNIT_MULT                  0
# UNIT_MULT_LABEL            0
# DATA_SOURCE                0
# DATA_SOURCE_LABEL         30
# UNIT_TYPE                 30
# UNIT_TYPE_LABEL            0
# TIME_FORMAT                0
# TIME_FORMAT_LABEL         30
# COMMENT_OBS               30
# OBS_STATUS                30
# OBS_STATUS_LABEL          30
# OBS_CONF                  30
# OBS_CONF_LABEL            30
# dtype: int64

# %%
# Check the percentage of missing values
(Data_on_Economic_Growth_indicator.isnull().sum()/(len(Data_on_Economic_Growth_indicator)))*100
# Out:
# STRUCTURE                  0.000000
# STRUCTURE_ID               0.000000
# ACTION                     0.000000
# FREQ                       0.000000
# FREQ_LABEL                 0.000000
# Country Code               0.000000
# Country Name               0.000000
# Series Code                0.000000
# Series Name                0.000000
# SEX                        0.000000
# SEX_LABEL                  0.000000
# AGE                        0.000000
# AGE_LABEL                  0.000000
# URBANISATION               0.000000
# URBANISATION_LABEL         0.000000
# UNIT_MEASURE               0.000000
# UNIT_MEASURE_LABEL         0.000000
# COMP_BREAKDOWN_1           0.000000
# COMP_BREAKDOWN_1_LABEL     0.000000
# COMP_BREAKDOWN_2           0.000000
# COMP_BREAKDOWN_2_LABEL     0.000000
# COMP_BREAKDOWN_3           0.000000
# COMP_BREAKDOWN_3_LABEL     0.000000
# Year                       0.000000
# OBS_VALUE                  0.000000
# DECIMALS                   0.000000
# DECIMALS_LABEL             0.000000
# DATABASE_ID                0.000000
# DATABASE_ID_LABEL          0.000000
# COMMENT_TS                41.176471
# UNIT_MULT                  0.000000
# UNIT_MULT_LABEL            0.000000
# DATA_SOURCE                0.000000
# DATA_SOURCE_LABEL         58.823529
# UNIT_TYPE                 58.823529
# UNIT_TYPE_LABEL            0.000000
# TIME_FORMAT                0.000000
# TIME_FORMAT_LABEL         58.823529
# COMMENT_OBS               58.823529
# OBS_STATUS                58.823529
# OBS_STATUS_LABEL          58.823529
# OBS_CONF                  58.823529
# OBS_CONF_LABEL            58.823529
# dtype: float64

# %% [markdown]
# - **Insight📣**
#
# - **High Null Percentage:**
# Features like ZONE1 and ZONE2 have exceptionally high null percentages (92.12% and 93.61% respectively), indicating that these attributes are mostly missing from the dataset.
#
# - **Moderate Null Percentage:**
# Features such as REGION, DATA_VOLUME, ON_NET, ORANGE, TIGO, TOP_PACK, and FREQ_TOP_PACK exhibit moderate null percentages ranging from 35% to 59.87%. While these attributes have a considerable number of missing values, they still contain substantial information that could be valuable for analysis. Imputation techniques or careful handling of missing data might be necessary to utilize these features effectively.
#
# - **Low Null Percentage:**
# Some features, such as MONTANT, FREQUENCE_RECH, REVENUE, ARPU_SEGMENT, and FREQUENCE, have relatively low null percentages ranging from 33.64% to 41.86%. Despite missing values, these attributes still retain a significant portion of the dataset and can potentially provide valuable insights into customer behavior and churn prediction. However, missing value imputation or careful analysis of these features' impact on the model may be required.
#
# - **No Null Values:**
# Features like user_id, TENURE, MRG, REGULARITY, and CHURN have no null values, indicating that they are complete and available for analysis without any preprocessing requirements.
#
# In conclusion, these missing values could indicate various scenarios, such as customers who haven't performed certain types of transactions or customers with incomplete usage records.

# %%
# Getting the summary statistics of numerical columns
Data_on_Economic_Growth_indicator.describe().T
# Out:
#            count        mean          std       min       25%       50%  \
# OBS_VALUE   51.0  843.576302  1047.168003 -1.794253  3.312574  6.200078
#
#                    75%          max
# OBS_VALUE  1940.655269  3222.692106

# %% [markdown]
# # Insight 📣
#
# AGE (Client Age):
# The average age of clients is 40.02 years, with a standard deviation of 10.42, indicating a diverse age distribution.
#
# The age ranges from 17 to 98, with most clients between 32 and 47 years old, suggesting the bank primarily engages with working-age individuals, but also includes younger and senior segments.
#
# DURATION (Call Duration in Seconds):
# The mean duration of the last contact is 258.32 seconds (~4.3 minutes), with a large standard deviation of 259.31, suggesting high variability in call engagement.
#
# The duration ranges from 0 to 4918 seconds (~82 minutes), showing that while some calls were extremely brief, others were extensive, likely indicating client interest.
#
# ⚠️ Note: Duration is highly correlated with the outcome (y), but it is only known after the call. Avoid using it in models predicting y before contact.
#
# CAMPAIGN (Contacts in Current Campaign):
# Clients were contacted on average 2.57 times, with a standard deviation of 2.77, indicating varied campaign persistence.
#
# Contacts range from 1 to 56, but 75% of clients were contacted 3 times or fewer, suggesting that high-frequency contact is rare.
#
# PDAYS (Days Since Previous Contact):
# The average pdays is 962.46, with a very low standard deviation (186.94) because most values are 999 — a code indicating the client was not contacted before.
#
# Since 75% of the values are 999, prior contact is uncommon, and this field is more useful as a binary flag (contacted previously or not).
#
# PREVIOUS (Previous Campaign Contacts):
# The mean number of past contacts is 0.17, with a maximum of 7, and 75% of clients had 0 previous contacts.
#
# This suggests most clients were new or inactive in previous campaigns.
#
# EMP.VAR.RATE (Employment Variation Rate):
# The average employment variation rate is 0.08, with values ranging from -3.4 to 1.4, indicating varying economic conditions during campaigns.
#
# Negative values suggest declining employment environments — possibly affecting client decisions.
#
# CONS.PRICE.IDX (Consumer Price Index):
# The average consumer price index is 93.58, with a narrow standard deviation (0.58), suggesting stable prices over the campaign period.
#
# Values range from 92.20 to 94.77, and subtle differences might reflect economic phases that could affect customer sentiment.
#
# CONS.CONF.IDX (Consumer Confidence Index):
# The mean confidence index is -40.50, with a standard deviation of 4.63, indicating generally pessimistic consumer sentiment.
#
# Index values vary from -50.8 to -26.9, with more negative values reflecting reduced trust in the economy, possibly influencing deposit decisions.
#
# EURIBOR3M (3-Month Euribor Rate):
# The average Euribor rate is 3.62, with a range from 0.63 to 5.05. A wide spread implies changing financial environments during the campaign.
#
# Higher rates could signal tighter credit conditions, which might affect client behavior toward savings or term deposits.
#
# NR.EMPLOYED (Number of Employees):
# The average number of employees is 5167.03, with values ranging from 4963.6 to 5228.1.
#
# This feature reflects broader economic conditions (e.g., job creation trends), and its near-steady value range suggests minor fluctuations in employment during the period.
#
# 🎯 Summary
# These insights reveal the economic context, client demographics, and engagement behavior during the marketing campaigns. Variability in features like duration, campaign contact counts, and economic indicators could have a strong influence on whether a client subscribes to a term deposit.
#
# Understanding these factors is key to:
#
# Improving campaign targeting
#
# Optimizing contact strategies
#
# Developing effective predictive models for client response

# %% [markdown]
# #### Save the dataset (cleaned) into a CSV file

# %%
# Saving the DataFrame to an Excel file

# Path to the folder outside the current notebook folder
# '..' means go one level up from the current directory
folder_path = '../dataset'

# Check if the folder exists, if not, create it
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Full path for the CSV file inside the 'dataset' folder
file_path = os.path.join(folder_path, 'Data_on_Economic_Growth_indicatorProcessed.csv')

# Save the DataFrame as a CSV in the folder
Data_on_Economic_Growth_indicator.to_csv(file_path, index=False)

print(f"File saved to {file_path}")
# Out:
# File saved to ../dataset\Data_on_Economic_Growth_indicatorProcessed.csv
